# %% [markdown]
# <a href="https://colab.research.google.com/github/Leandro-Bernardo/Neural-Network-for-fire-detection/blob/main/5_Gr%C3%A1ficos_Accuracy_15_x_Epoch_(histograma).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/TCC/Scripts/Modelos'
# Out:
# /content/drive/MyDrive/TCC/Scripts/Modelos

# %%
# !pwd
# Out:
# /content/drive/MyDrive/TCC/Scripts/Modelos

# %% [markdown]
# #### Dados

# %%
nome = 'epochs'  # nome para as colunas do DataFrame

# %%
epochs = list(range(1001))
epochs.remove(0)

# %%
import os

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ##### 100 Treinamentos

# %% [markdown]
# ###### Modelo 1  (100)

# %%
os.listdir('/content/drive/MyDrive/TCC/Scripts/Modelos')
# Out:
# ['model4(1000)t.txt',
#  'model6(1000)t.txt',
#  'model6(1000)t(2rodada).txt',
#  'model5(1000)t.txt',
#  'model1(100)(Acc_Epoch).txt',
#  'model2(100)(Acc_Epoch).txt',
#  'model3(100)(Acc_Epoch).txt',
#  'model4(100)(Acc_Epoch).txt',
#  'model5(100)(Acc_Epoch).txt',
#  'model6(100)(Acc_Epoch).txt',
#  'model7(100)(Acc_Epoch).txt',
#  'model8(100)(AccxEpoch).txt',
#  'model??(789t).txt',
#  'model8(396)(AccxEpoch).txt',
#  'model8(1000)t.txt',
#  'model7(1000)t.txt',
#  'Teste de Validação (modelo 7)',
#  'model7(1000)t(Acc*Epoch)(banco_de_dados_antigo).txt',
#  'model10(1000)t(Acc*Epoch).txt',
#  'modelo7(1t)accxepoch.txt',
#  'model9(1000)(AccxEpoch).txt',
#  'model7(250)(AccxEpoch).treinamento_novo(664imagens).txt']

# %%
import pandas as pd

# %%
#modelo_1 = pd.read_csv('model1(100)t.txt', index_col = 'Treinamento')
#modelo_1

# %%
#!pwd

# %%
#acc = [0.9910714030265808, 0.9910714030265808, 0.9776785969734192, 0.5758928656578064, 0.8883928656578064, 0.9910714030265808, 0.8125, 0.8080357313156128, 0.9821428656578064, 0.8883928656578064, 0.5982142686843872, 0.9910714030265808, 0.9776785969734192, 0.8705357313156128, 0.9419642686843872, 0.9821428656578064, 0.9776785969734192, 0.8258928656578064, 0.7723214030265808, 0.9866071343421936, 0.9866071343421936, 0.9241071343421936, 0.7633928656578064, 0.9419642686843872, 0.9866071343421936, 0.8928571343421936, 0.9955357313156128, 0.5848214030265808, 0.9910714030265808, 0.9776785969734192, 0.9821428656578064, 1.0, 0.9821428656578064, 0.6964285969734192, 0.96875, 0.9866071343421936, 0.7276785969734192, 0.9776785969734192, 0.9375, 0.9821428656578064, 0.96875, 0.6741071343421936, 0.9866071343421936, 0.6160714030265808, 0.8883928656578064, 0.9910714030265808, 0.9196428656578064, 0.6919642686843872, 0.9910714030265808, 0.7455357313156128, 0.9776785969734192, 0.8660714030265808, 0.9419642686843872, 0.9508928656578064, 0.5758928656578064, 0.8839285969734192, 0.9732142686843872, 0.9598214030265808, 0.9598214030265808, 0.875, 0.96875, 0.8794642686843872, 0.9776785969734192, 0.6651785969734192, 0.9821428656578064, 0.8214285969734192, 0.6696428656578064, 0.9732142686843872, 0.9866071343421936, 0.9821428656578064, 0.9821428656578064, 0.9776785969734192, 0.7901785969734192, 0.5758928656578064, 0.9017857313156128, 0.9419642686843872, 0.9285714030265808, 0.9732142686843872, 0.9241071343421936, 0.9821428656578064, 0.5848214030265808, 0.9330357313156128, 0.9910714030265808, 0.9330357313156128, 0.90625, 0.9241071343421936, 0.9821428656578064, 0.9285714030265808, 0.9776785969734192, 0.9107142686843872, 0.6785714030265808, 0.90625, 0.9732142686843872, 0.9821428656578064, 0.5803571343421936, 0.9866071343421936, 0.9107142686843872, 0.7142857313156128, 0.9107142686843872, 0.8973214030265808]

# %%
#modelo_1 = pd.DataFrame(data = acc, index = epochs).rename(columns = {0:'Accuracy'})
#modelo_1.transpose()

# %% [markdown]
# ###### Modelo 2 (100)

# %%
import pandas as pd

# %%
#modelo_2 = pd.read_csv('model 2.txt').transpose()

# %%
# acc2= [0.9419642686843872, 0.9910714030265808, 1.0, 0.9910714030265808, 0.5848214030265808, 0.9955357313156128, 0.9553571343421936, 1.0, 1.0, 0.8392857313156128, 0.5848214030265808, 1.0, 0.9910714030265808, 0.8482142686843872, 1.0, 0.9285714030265808, 0.9241071343421936, 0.9955357313156128, 1.0, 0.5848214030265808, 0.9375, 0.9598214030265808, 0.7053571343421936, 0.8883928656578064, 1.0, 0.9955357313156128, 0.5848214030265808, 0.9419642686843872, 0.9955357313156128, 0.8794642686843872, 0.9955357313156128, 0.6071428656578064, 0.9598214030265808, 0.9910714030265808, 0.6026785969734192, 0.9955357313156128, 0.8392857313156128, 0.5848214030265808, 0.9910714030265808, 1.0, 0.6339285969734192, 0.9821428656578064, 1.0, 0.5535714030265808, 0.5848214030265808, 0.6741071343421936, 0.9732142686843872, 0.9910714030265808, 0.6473214030265808, 0.96875, 0.6473214030265808, 0.9955357313156128, 0.5848214030265808, 1.0, 0.5848214030265808, 0.6383928656578064, 1.0, 0.5848214030265808, 0.8526785969734192, 0.7232142686843872, 0.53125, 0.9955357313156128, 0.9642857313156128, 0.5848214030265808, 0.7276785969734192, 1.0, 0.5848214030265808, 0.5848214030265808, 1.0, 0.9598214030265808,0.5848214030265808, 0.9776785969734192, 0.7366071343421936, 0.5848214030265808, 0.9642857313156128, 0.9732142686843872, 0.75, 0.5848214030265808, 0.5848214030265808, 0.9017857313156128, 0.5848214030265808, 0.9866071343421936, 0.96875, 0.9955357313156128, 0.5223214030265808, 0.8348214030265808, 0.7455357313156128, 0.9196428656578064, 1.0, 0.8482142686843872, 0.9910714030265808, 0.9955357313156128, 1.0, 0.9955357313156128, 0.875, 0.6830357313156128, 0.7678571343421936, 0.5848214030265808, 0.9955357313156128,0.95]
# modelo_2 = pd.DataFrame(data = acc2, index = epochs).rename(columns = {0:'Accuracy'})
# modelo_2.transpose()

# %% [markdown]
# ###### Modelo 3 (100)

# %%
import pandas as pd

# %%
acc3 = [0.7589285969734192, 0.8392857313156128, 0.8571428656578064, 0.75, 0.6026785969734192, 0.5714285969734192, 0.6026785969734192, 0.6339285969734192, 0.8571428656578064, 0.5044642686843872, 0.6517857313156128, 0.7455357313156128, 0.5848214030265808, 0.6339285969734192, 0.8526785969734192, 0.96875, 0.5491071343421936, 0.6919642686843872, 0.5491071343421936, 0.6205357313156128, 0.8839285969734192, 0.7053571343421936, 0.6339285969734192, 0.7276785969734192, 0.5714285969734192, 0.59375, 0.7544642686843872, 0.5848214030265808, 0.7991071343421936, 0.7633928656578064, 0.5848214030265808, 0.6651785969734192, 0.53125, 0.9642857313156128, 0.8526785969734192, 0.7142857313156128, 0.5580357313156128, 0.8169642686843872, 0.5446428656578064, 0.6339285969734192, 0.6741071343421936, 0.8705357313156128, 0.6607142686843872, 0.7544642686843872, 0.6071428656578064, 0.5982142686843872, 0.6026785969734192, 0.6517857313156128, 0.5401785969734192, 0.5848214030265808, 0.5848214030265808, 0.5892857313156128, 0.6473214030265808, 0.78125, 0.59375, 0.8214285969734192, 0.78125, 0.5669642686843872, 0.5848214030265808, 0.6651785969734192, 0.5848214030265808, 0.5848214030265808, 0.6651785969734192, 0.6428571343421936, 0.5848214030265808, 0.8214285969734192, 0.6160714030265808, 0.7901785969734192, 0.5758928656578064, 0.7857142686843872, 0.625, 0.7410714030265808, 0.5848214030265808, 0.5357142686843872, 0.5848214030265808, 0.6339285969734192, 0.5669642686843872, 0.5714285969734192, 0.5848214030265808, 0.6294642686843872, 0.6964285969734192, 0.9330357313156128, 0.6294642686843872, 0.7544642686843872, 0.5848214030265808, 0.71875, 0.7767857313156128, 0.9866071343421936, 0.5535714030265808, 0.6785714030265808, 0.6473214030265808, 0.5848214030265808, 0.9553571343421936, 0.5803571343421936, 0.84375, 0.9330357313156128, 0.9375, 0.5848214030265808, 0.6428571343421936, 0.7232142686843872]

# %%
# #modelo_3 = pd.read_csv('model 3.txt')
# modelo_3 = pd.DataFrame(data = acc3, index = epochs).rename(columns = {0:'Accuracy'})

# %%
# modelo_3.transpose()

# %% [markdown]
# ##### 1000 Treinamentos

# %% [markdown]
# ###### Modelo 8  (1000)

# %%
os.listdir('/content/drive/MyDrive/TCC/Scripts/Modelos')
# Out:
# ['model4(1000)t.txt',
#  'model6(1000)t.txt',
#  'model6(1000)t(2rodada).txt',
#  'model5(1000)t.txt',
#  'model1(100)(Acc_Epoch).txt',
#  'model2(100)(Acc_Epoch).txt',
#  'model3(100)(Acc_Epoch).txt',
#  'model4(100)(Acc_Epoch).txt',
#  'model5(100)(Acc_Epoch).txt',
#  'model6(100)(Acc_Epoch).txt',
#  'model7(100)(Acc_Epoch).txt',
#  'model8(100)(AccxEpoch).txt',
#  'model??(789t).txt',
#  'model8(396)(AccxEpoch).txt',
#  'model8(1000)t.txt',
#  'model7(1000)t.txt',
#  'Teste de Validação (modelo 7)',
#  'model7(1000)t(Acc*Epoch)(banco_de_dados_antigo).txt',
#  'model10(1000)t(Acc*Epoch).txt',
#  'modelo7(1t)accxepoch.txt',
#  'model9(1000)(AccxEpoch).txt',
#  'model7(250)(AccxEpoch).treinamento_novo(664imagens).txt']

# %%
import pandas as pd

# %%
modelo_8 = pd.read_csv('model8(1000)t.txt', index_col=0)
modelo_8
# Out:
#              Accuracy
# Treinamento
# 1            0.959821
# 2            0.986607
# 3            0.982143
# 4            0.986607
# 5            0.995536
# ...               ...
# 414          0.910714
# 415          1.000000
# 416          1.000000
# 417          1.000000
# 418          1.000000
#
# [1397 rows x 1 columns]

# %%
#fig= px.scatter(modelo_1,x=modelo_1['Accuracy'] ,template = 'plotly_white', title= 'Modelo 1',width=800, height=500, color_discrete_sequence=['light blue'])
#fig.show()

fig= px.histogram(modelo_8, x='Accuracy' ,template = 'plotly_white', title= 'Modelo 8',width=800, height=500, color_discrete_sequence=['light blue'], nbins = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Modelo 7  (1000)

# %%
os.listdir('/content/drive/MyDrive/TCC/Scripts/Modelos')
# Out:
# ['model4(1000)t.txt',
#  'model6(1000)t.txt',
#  'model6(1000)t(2rodada).txt',
#  'model5(1000)t.txt',
#  'model1(100)(Acc_Epoch).txt',
#  'model2(100)(Acc_Epoch).txt',
#  'model3(100)(Acc_Epoch).txt',
#  'model4(100)(Acc_Epoch).txt',
#  'model5(100)(Acc_Epoch).txt',
#  'model6(100)(Acc_Epoch).txt',
#  'model7(100)(Acc_Epoch).txt',
#  'model8(100)(AccxEpoch).txt',
#  'model??(789t).txt',
#  'model8(396)(AccxEpoch).txt',
#  'model8(1000)t.txt',
#  'model7(1000)t.txt',
#  'Teste de Validação (modelo 7)',
#  'model7(1000)t(Acc*Epoch)(banco_de_dados_antigo).txt',
#  'model10(1000)t(Acc*Epoch).txt',
#  'modelo7(1t)accxepoch.txt',
#  'model9(1000)(AccxEpoch).txt',
#  'model7(250)(AccxEpoch).treinamento_novo(664imagens).txt']

# %%
import pandas as pd

# %%
modelo_7 = pd.read_csv('model7(1000)t.txt', index_col=0)
modelo_7
# Out:
#              Accuracy
# Treinamento
# 1            0.928571
# 2            0.973214
# 3            0.968750
# 4            0.866071
# 5            0.991071
# ...               ...
# 996          0.995536
# 997          1.000000
# 998          0.959821
# 999          0.995536
# 1000         0.982143
#
# [1000 rows x 1 columns]

# %%
modelo_7[modelo_7.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Accuracy]
# Index: []

# %%
#fig= px.scatter(modelo_1,x=modelo_1['Accuracy'] ,template = 'plotly_white', title= 'Modelo 1',width=800, height=500, color_discrete_sequence=['light blue'])
#fig.show()

fig= px.histogram(modelo_7, x='Accuracy' ,template = 'plotly_white', title= 'Modelo 7',width=800, height=500, color_discrete_sequence=['light blue'], nbins = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Modelo 6 (1000)

# %%
import pandas as pd

# %%
modelo_6 = pd.read_csv('model6(1000)t.txt', index_col = 0)
modelo_6
# Out:
#              Accuracy
# Treinamento
# 1            0.750000
# 2            0.982143
# 3            0.772321
# 4            0.723214
# 5            0.629464
# ...               ...
# 996          0.790179
# 997          0.991071
# 998          0.910714
# 999          0.866071
# 1000         0.772321
#
# [1000 rows x 1 columns]

# %%
#fig= px.scatter(modelo_2,x='Accuracy' ,template = 'plotly_white', title= 'Modelo 2',width=800, height=500, color_discrete_sequence=['firebrick'])
#fig.show()

fig= px.histogram(modelo_6,x='Accuracy',template = 'plotly_white' , title= 'Modelo 6',width=800, height=500, color_discrete_sequence=['firebrick'], nbins = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Modelo 5 (1000)

# %%
import pandas as pd

# %%
modelo_5 = pd.read_csv('model5(1000)t.txt')
modelo_5
# Out:
#      Treinamento  Accuracy
# 0              1  0.892857
# 1              2  0.741071
# 2              3  0.843750
# 3              4  0.910714
# 4              5  0.584821
# ..           ...       ...
# 995          996  0.924107
# 996          997  0.973214
# 997          998  0.982143
# 998          999  1.000000
# 999         1000  1.000000
#
# [1000 rows x 2 columns]

# %%
#fig= px.scatter(modelo_3,x='Accuracy' ,template = 'plotly_white', title= 'Modelo 3',width=800, height=500, color_discrete_sequence=['green'])
#fig.show()

fig= px.histogram(modelo_5,x='Accuracy' ,template = 'plotly_white', title= 'Modelo 5',width=800, height=500, color_discrete_sequence=['green'], nbins = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Modelo 4 (1000)

# %%
import pandas as pd

# %%
modelo_4 = pd.read_csv('model4(1000)t.txt')
modelo_4
# Out:
#      Treinamento  Accuracy
# 0              1  0.709821
# 1              2  0.857143
# 2              3  0.915179
# 3              4  0.928571
# 4              5  0.584821
# ..           ...       ...
# 995          996  0.638393
# 996          997  0.861607
# 997          998  0.647321
# 998          999  0.995536
# 999         1000  0.946429
#
# [1000 rows x 2 columns]

# %%
#fig= px.scatter(modelo_4,x='Accuracy' ,template = 'plotly_white', title= 'Modelo 3',width=800, height=500, color_discrete_sequence=['mediumpurple'])
#fig.show()

fig= px.histogram(modelo_4,x='Accuracy' ,template = 'plotly_white', title= 'Modelo 4',width=800, height=500, color_discrete_sequence=['mediumpurple'], nbins = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Gráficos

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %%
 modelos = pd.DataFrame()

# # transformando em percentual
modelos['Modelo 8'] = modelo_8['Accuracy']*100
modelos['Modelo 7'] = modelo_7['Accuracy']*100
modelos['Modelo 6'] = modelo_6['Accuracy']*100
modelos['Modelo 5'] = modelo_5['Accuracy']*100
modelos['Modelo 4'] = modelo_4['Accuracy']*100
modelos
# Out:
#                Modelo 8    Modelo 7   Modelo 6   Modelo 5   Modelo 4
# Treinamento
# 1             95.982140   92.857140  75.000000  74.107140  85.714287
# 2             98.660713   97.321427  98.214287  84.375000  91.517860
# 3             98.214287   96.875000  77.232140  91.071427  92.857140
# 4             98.660713   86.607140  72.321427  58.482140  58.482140
# 5             99.553573   99.107140  62.946427  58.482140  61.607140
# ...                 ...         ...        ...        ...        ...
# 414           91.071427   99.553573  96.428573  72.767860  55.357140
# 415          100.000000   99.553573  98.660713  58.482140  58.482140
# 416          100.000000   99.107140  66.964287  58.482140  79.464287
# 417          100.000000   99.553573  99.107140  98.214287  90.178573
# 418          100.000000  100.000000  83.928573  99.553573  52.232140
#
# [1397 rows x 5 columns]

# %%
fig= px.histogram(modelos ,template = 'plotly_white', title= 'Histograma dos Modelos',
                  width=1200, height=600, nbins = 600
                  ,color_discrete_sequence = ['lightpink','dodgerblue','tomato', 'slategrey', 'chartreuse'])
fig.update_layout(font_size = 18)
fig['layout']['xaxis']['title']['text'] = 'Accuracy (%)'
fig['layout']['yaxis']['title']['text'] = 'Contagem (Individual)'

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#modelos = pd.DataFrame()
#modelos['Modelo 1'] , modelos['Modelo 2'] , modelos['Modelo 3']  = modelo_1['Accuracy'], modelo_2['Accuracy'], modelo_3['Accuracy']

#fig = px.histogram(modelos, x = ['Modelo 1', 'Modelo 2', 'Modelo 3'],y = modelos.index ,template = 'plotly_white',width=1200, height=700,nbins = 100)
#fig['layout']['yaxis']['title']['text'] = 'Eixo y'
#fig.show()

# %%
modelos['Modelo 1'] = modelo_1['Accuracy'].mean()
modelos['Modelo 2'] = modelo_2['Accuracy'].mean()
modelos['Modelo 3'] = modelo_3['Accuracy'].mean()
modelos['Modelo 4'] = modelo_4['Accuracy']
modelos
# Out:
#              Modelo 1  Modelo 2  Modelo 3  Modelo 4   Modelo 5
# Treinamento
# 1            0.972782  0.841951  0.852906  0.857143  91.287881
# 2            0.972782  0.841951  0.852906  0.915179  90.909094
# 3            0.972782  0.841951  0.852906  0.928571  79.924244
# 4            0.972782  0.841951  0.852906  0.584821  82.575756
# 5            0.972782  0.841951  0.852906  0.616071  85.984850
# ...               ...       ...       ...       ...        ...
# 996          0.972782  0.841951  0.852906  0.861607        NaN
# 997          0.972782  0.841951  0.852906  0.647321        NaN
# 998          0.972782  0.841951  0.852906  0.995536        NaN
# 999          0.972782  0.841951  0.852906  0.946429        NaN
# 1000         0.972782  0.841951  0.852906       NaN        NaN
#
# [1001 rows x 5 columns]

# %%
media_m1 = modelo_1['Accuracy'].mean()
media_m2 = modelo_2['Accuracy'].mean()
media_m3 = modelo_3['Accuracy'].mean()
media_m4 = modelo_4['Accuracy'].mean()
media_m5 = modelo_5['Accuracy'].mean()

# %%
print(media_m1, media_m2, media_m3, media_m4, media_m5)
# Out:
# 0.9727816822288277 0.8419508906006813 0.8529062470197678 0.6878839253485203 0.8799047926381816

# %%
#with open('/content/drive/MyDrive/TCC/Scripts/Modelos/model5novo','w') as m:
#    m.write('')

# %%
# count = 0
# for i,j in enumerate(open('/content/drive/MyDrive/TCC/Scripts/Modelos/model5(500)t.txt')):
#   splited = j.split(', ')
#   splited[0] = count+501
#   count+=1
#   print(splited)
#   with open('/content/drive/MyDrive/TCC/Scripts/Modelos/model5novo','a+') as m:
#     m.write(f'{splited[0]}, {splited[1]}')
