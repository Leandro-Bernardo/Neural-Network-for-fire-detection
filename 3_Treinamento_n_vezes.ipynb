# %% [markdown]
# <a href="https://colab.research.google.com/github/Leandro-Bernardo/Neural-Network-for-fire-detection/blob/main/3_Treinamento_n_vezes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Pré processamento das Imagens

# %%
import os

# %%
local = '/content/drive/MyDrive/Artigos Científicos/Rede Neural/Treinamento_N3/alpha_40'#input('Qual Treinamento?')

# %%
#local aonde as imagens estão sendo geradas
path = '/content'

# local aonde os arquivos serão salvos
path_destino = '/content/drive/MyDrive/Artigos Científicos/Rede Neural/Resultados'

# %%
dir = list(os.listdir(local))
dir

# %%
print(f'{dir[0]} contem :', len(os.listdir(f'{local}/{dir[0]}')),'fotos')
print(f'{dir[1]} contem :', len(os.listdir(f'{local}/{dir[1]}')),'fotos')

size = sum([len(os.listdir(f'{local}/{dir[0]}')) ,len(os.listdir(f'{local}/{dir[1]}'))])
print('Total:', size)
# Out:
# Fumaca contem : 3760 fotos
# Nao_Fumaca contem : 3080 fotos
# Total: 6840

# %%
amostras = int(size/128)
amostras
# Out:
# 53

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Para reescalar as imagens em 1./255  (normalizar)
reescala = ImageDataGenerator(rescale=1/255)

# Flow training images in batches using train_datagen generator
imagens_treinamento = reescala.flow_from_directory(
        local,  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size= amostras,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 6840 images belonging to 2 classes.

# %% [markdown]
# #### Modelos

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop

# %%
class CustomCallback(keras.callbacks.Callback):     # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/Callback
  def on_epoch_end(self, epoch, logs=None):
        keys = list(logs.values())
#        print("Epoch {} ; accuracy: {}".format(epoch, keys[1]))

# %% [markdown]
# ##### Modelo 1

# %%
def modelo_1():  # 15 epochs, learning rate 0.01 ,  5 layers de convolução  
  rede = tf.keras.models.Sequential([
    
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid).   
    tf.keras.layers.Dense(1, activation='sigmoid')])    #Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)
  
  rede.compile(loss='binary_crossentropy', 
               optimizer=RMSprop(learning_rate=0.01), 
               metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 2

# %%
def modelo_2():  # 15 epochs, learning rate 0.01 ,  4 layers de convolução  
  rede = tf.keras.models.Sequential([
    
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid).   
    tf.keras.layers.Dense(1, activation='sigmoid')])    #Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)
  
  rede.compile(loss='binary_crossentropy', 
               optimizer=RMSprop(learning_rate=0.01), 
               metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 3

# %%
def modelo_3():  # 15 epochs, learning rate 0.01 ,  4 layers de convolução  
  rede = tf.keras.models.Sequential([
    
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid).   
    tf.keras.layers.Dense(1, activation='sigmoid')])    #Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)
  
  rede.compile(loss='binary_crossentropy', 
               optimizer=RMSprop(learning_rate=0.01), 
               metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 4

# %%
def modelo_4(): # 15 epochs, learning rate 0.001 ,  3 layers de convolução  
  rede = tf.keras.models.Sequential([
    

    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
 
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid). Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)  
    tf.keras.layers.Dense(1, activation='sigmoid')])
  
  rede.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.02),
              metrics=['accuracy'])
  return rede

# %% [markdown]
# ##### Modelo 5

# %%
def modelo_5(): # 15 epochs, learning rate 0.002 ,  5 layers de convolução  (5 tentativa)
  rede = tf.keras.models.Sequential([
    
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid). Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)  
    tf.keras.layers.Dense(1, activation='sigmoid')])
  
  rede.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.002),
              metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 6

# %%
def modelo_6():  # 15 epochs, learning rate 0.002 ,  4 layers de convolução 
  rede = tf.keras.models.Sequential([
    
    # Primeira Convolução  (nos dados iniciais) 
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(256, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid).   
    tf.keras.layers.Dense(1, activation='sigmoid')])    #Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)
  
  rede.compile(loss='binary_crossentropy', 
               optimizer=RMSprop(learning_rate=0.002), 
               metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 7

# %%
def modelo_7():  # 16 epochs, learning rate 0.001 ,  4 layers de convolução  
  rede = tf.keras.models.Sequential([
    
    # Primeira Convolução  (nos dados iniciais) 
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(256, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid).   
    tf.keras.layers.Dense(1, activation='sigmoid')])    #Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)
  
  rede.compile(loss='binary_crossentropy', 
               optimizer=RMSprop(learning_rate=0.001), 
               metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 8

# %%
def modelo_8(): #  10 epochs, learning rate 0.001 ,  5 layers de convolução  
  rede = tf.keras.models.Sequential([
    
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid). Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)  
    tf.keras.layers.Dense(1, activation='sigmoid')])
  
  rede.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 9

# %%
def modelo_9():  # 27 epochs, learning rate 0.001 ,  4 layers de convolução  (atual)
  rede = tf.keras.models.Sequential([
    
    # Primeira Convolução  (nos dados iniciais) 
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(256, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid).   
    tf.keras.layers.Dense(1, activation='sigmoid')])    #Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)
  
  rede.compile(loss='binary_crossentropy', 
               optimizer=RMSprop(learning_rate=0.001), 
               metrics=['accuracy'])
  
  return rede

# %% [markdown]
# ##### Modelo 10

# %%
def modelo_10(): # modelo 8 com 15 epochs, learning rate 0.001 ,  5 layers de convolução  
  rede = tf.keras.models.Sequential([
    
    # tf.keras.layers.Conv2D ( numero de filtros , matriz n x n, função de ativação, dados de entrada)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), # input_shape(linhas, colunas, camadas (de cor))
    tf.keras.layers.MaxPooling2D(2, 2),  # max pool usando uma matriz n x n

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten os resultados para usar na Rede Neural Densa
    tf.keras.layers.Flatten(),

    # tf.keras.layers.Dense( N, função) cria uma Hidden Layer com N neuronios
    tf.keras.layers.Dense(512, activation='relu'),

    # Só um neurônio de saída por causa da função de ativação (Sigmoid). Esse neurônio recebe valor 0 ou 1 (0 para classe 1 e 1 para a outra classe)  
    tf.keras.layers.Dense(1, activation='sigmoid')])
  
  rede.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])
  
  return rede

# %%
class CustomCallback(keras.callbacks.Callback):     # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/Callback
  def on_epoch_end(self, epoch, logs=None):
        keys = list(logs.values())
#        print("Epoch {} ; accuracy: {}".format(epoch, keys[1]))

# %% [markdown]
# #### Accuracy x Epoch ( todas )

# %%
import shutil

# %%
n = int(input('quantos treinamentos?  '))
# Out:
# quantos treinamentos?  100

# %%
os.chdir(path_destino)  # muda para o diretorio aonde os dados serão salvos

# %% [markdown]
# ##### Modelo 1

# %%
acc1 = list(range(n))

nome = f'model1({n})(Acc*Epoch)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model1 = modelo_1()
    report1 = model1.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report1.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 2

# %%
acc2 = list(range(n))

nome = f'model2({n})(Acc*Epoch)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model2 = modelo_2()
    report2 = model2.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report2.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 3

# %%
acc3 = list(range(n))

nome = f'model3({n})(AccxEpoch)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model3 = modelo_3()
    report3 = model3.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report3.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 4

# %%
acc4 = list(range(n))

nome = f'model1({n})(AccxEpoch)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model4 = modelo_4()
    report4 = model4.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report4.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 5

# %%
acc5 = list(range(n))

nome = f'model5({n})(AccxEpoch)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model5 = modelo_5()
    report5 = model5.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report5.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 6

# %%
acc6 = list(range(n))

nome = f'model6({n})(AccxEpoch)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model6 = modelo_6()
    report6 = model6.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report6.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 7

# %%
acc7 = list(range(n))

nome = f'model7({n})(AccxEpoch).treinamento_novo(664imagens)'
epoch = 16 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model7 = modelo_7()
    report7 = model7.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report7.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 8

# %%
acc8 = list(range(n))

nome = f'model8({n})(AccxEpoch)(664)' 
epoch = 15 

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model8 = modelo_8()
    report8 = model8.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report8.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 9

# %%
acc9 = list(range(n))

nome = f'model9({n})(AccxEpoch)' 
epoch =  27

passo = 8 # step per epoch
try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model9 = modelo_9()
    report9 = model9.fit(imagens_treinamento,
              steps_per_epoch=passo,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              #verbose=2,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report9.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')

# %% [markdown]
# ##### Modelo 10

# %%
acc10 = list(range(n))

nome = f'model10({n})(AccxEpoch)(alpha40)' 
epoch = 15

passo = 8 # step per epoch

try:
  assert f'{nome}.txt' not in os.listdir(f'{path_destino}')  # verifica se existe o arquivo no drive

except:
  print(f'{nome}.txt  já existe em {path_destino}')
  
else:
  with open(f'{nome}.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
   for i in range(1,epoch+1):
    m.write(f'{i},')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model10 = modelo_10()
    report10 = model10.fit(imagens_treinamento,
              steps_per_epoch=passo,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=epoch,     
              verbose=1,
              callbacks= [CustomCallback()])
    
    for j,acc in enumerate(report10.history['accuracy']):
      if j ==0:
        with open(f'{nome}.txt', 'a+') as m:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
          m.write(f'\n,{acc},') 
      else:
        with open(f'{nome}.txt', 'a+') as m:    
          m.write(f'{acc},')

try:
  shutil.move(f'{path}/{nome}.txt', f'{path_destino}')

except:
  print('modelo nao foi movido ou modelo já existe no path')
# Out:
#  treinamento 1
#
# Epoch 1/15

# %%
# %cd path_destino

# %% [markdown]
# #### Accuracy x Epoch ( ultima )

# %%
import shutil

# %%
n = int(input('quantos treinamentos?  '))
# Out:
# quantos treinamentos?  1000

# %%
# %cd '/content/drive/MyDrive/TCC/Videos'
# Out:
# /content/drive/MyDrive/TCC/Videos

# %%
acc1 = list(range(n))
  

try:
  assert f'model1({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model1({n})  já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model1({n})t.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
    m.write('Treinamento,Accuracy\n')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model1 = modelo_1()
    report1 = model1.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=0,
              callbacks= [CustomCallback()])

    acc1[i] = report1.history['accuracy'][-1]

    with open(f'model1({n})t.txt', 'a+') as m:    # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc1[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model1({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')

except:
  print('modelo nao foi movido')

# %%
acc2 = list(range(n))

try:
  assert f'model2({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model2({n}) já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model2({n})t.txt', 'w') as m:    # cria o arquivo para receber os valores 
    m.write('Treinamento,Accuracy\n')
  for i in range(n):
    print(f'\n treinamento {i+1} \n')

    model2 = modelo_2()
    report2 = model2.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=0,
              callbacks= [CustomCallback()])
    
    acc2[i] = report2.history['accuracy'][-1]

    with open(f'model2({n})t.txt', 'a+') as m:   # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc2[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model2({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')
  
except:
  pass
  print('modelo 2 nao foi movido')

# %%
acc3 = list(range(n))

try:
  assert f'model3({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model3({n})t já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model3({n})t.txt', 'w') as m:    # cria o arquivo para receber os valores 
    m.write('Treinamento,Accuracy\n')  
  for i in range(n):
    print(f'\n treinamento {i} \n')
    
    model3 = modelo_3()
    report3 = model3.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=0,
              callbacks= [CustomCallback()])

    acc3[i] = report3.history['accuracy'][-1]
    with open(f'model3({n})t.txt', 'a+') as m:   # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc3[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model3({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')
  
except:
  pass
  print('modelo 3 nao foi movido')

# %%
acc4 = list(range(n))

try:
  assert f'model4({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model4({n})t já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model4({n})t.txt', 'w') as m:    # cria o arquivo para receber os valores 
    m.write('Treinamento,Accuracy\n')  
  for i in range(n):
    print(f'\n treinamento {i} \n')
    
    model4 = modelo_4()
    report4 = model4.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=0,
              callbacks= [CustomCallback()])

    acc4[i] = report4.history['accuracy'][-1]
    with open(f'model4({n})t.txt', 'a+') as m:   # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+896}, {acc4[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model4({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')
  
except:
  pass
  print('modelo 4 nao foi movido')

# %%
acc5 = list(range(n))

try:
  assert f'model5({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model5({n}) já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model5({n})t.txt', 'w') as m:    # cria o arquivo para receber os valores 
    m.write('Treinamento,Accuracy\n')
  for i in range(n):
    print(f'\n treinamento {i+1} \n')

    model5 = modelo_5()
    report5 = model5.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=0,
              callbacks= [CustomCallback()])
    
    acc5[i] = report5.history['accuracy'][-1]

    with open(f'model5({n})t.txt', 'a+') as m:   # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc5[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model5({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')
  
except:
  pass
  print('modelo 5 nao foi movido')

# %%
acc6 = list(range(n))

try:
  assert f'model6({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model6({n}) já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model6({n})t.txt', 'w') as m:    # cria o arquivo para receber os valores 
    m.write('Treinamento,Accuracy\n')
  for i in range(n):
    print(f'\n treinamento {i+1} \n')

    model6 = modelo_6()
    report6 = model6.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=0,
              callbacks= [CustomCallback()])
    
    acc6[i] = report6.history['accuracy'][-1]

    with open(f'model6({n})t.txt', 'a+') as m:   # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc6[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model6({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')
  
except:
  pass
  print('modelo 6 nao foi movido')

# %%
acc7 = list(range(n))

try:
  assert f'model7({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model7({n}) já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model7({n})t.txt', 'w') as m:    # cria o arquivo para receber os valores 
    m.write('Treinamento,Accuracy\n')
  for i in range(n):
    print(f'\n treinamento {i+1} \n')

    model7 = modelo_7()
    report7 = model7.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=16,     
              verbose=0,
              callbacks= [CustomCallback()])
    
    acc7[i] = report2.history['accuracy'][-1]

    with open(f'model7({n})t.txt', 'a+') as m:   # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc7[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model7({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')
  
except:
  pass
  print('modelo 7 nao foi movido')

# %%
acc8 = list(range(n))
  

try:
  assert f'model8({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

except:
  print(f'model8({n})  já existe em /content/drive/MyDrive/TCC/Videos')
  
else:
  with open(f'model8({n})t.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
    m.write('Treinamento,Accuracy\n')

  for i in range(n): 
    print(f'\n treinamento {i+1} \n')

    model8  = modelo_8()
    report8 = model8.fit(imagens_treinamento,
              steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
              epochs=15,     
              verbose=1,
              callbacks= [CustomCallback()])

    acc8[i] = report8.history['accuracy'][-1]

    with open(f'model8({n})t.txt', 'a+') as m:    # 'a+' adiciona ao arquivo existente os valores
      m.write(f'{i+1}, {acc8[i]} \n')

try:
  shutil.move(f'/content/drive/MyDrive/TCC/Videos/model5({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')

except:
  print('modelo nao foi movido')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0869 - accuracy: 0.9777
# Epoch 11/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.3810 - accuracy: 0.9420
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 104ms/step - loss: 8.2454e-04 - accuracy: 1.0000
#
#  treinamento 245
#
# Epoch 1/15
# 8/8 [==============================] - 2s 102ms/step - loss: 0.7457 - accuracy: 0.4866
# Epoch 2/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6870 - accuracy: 0.5804
# Epoch 3/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6565 - accuracy: 0.7143
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5434 - accuracy: 0.7321
# Epoch 5/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.4804 - accuracy: 0.8036
# Epoch 6/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3615 - accuracy: 0.8482
# Epoch 7/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1913 - accuracy: 0.9598
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0510 - accuracy: 0.9866
# Epoch 9/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1406 - accuracy: 0.9732
# Epoch 10/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0302 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0461 - accuracy: 0.9821
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0209 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0321 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0110 - accuracy: 1.0000
#
#  treinamento 246
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.8893 - accuracy: 0.5982
# Epoch 2/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6591 - accuracy: 0.6875
# Epoch 3/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6290 - accuracy: 0.6696
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5762 - accuracy: 0.7589
# Epoch 5/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.5777 - accuracy: 0.7143
# Epoch 6/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5277 - accuracy: 0.8080
# Epoch 7/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3478 - accuracy: 0.9152
# Epoch 8/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2524 - accuracy: 0.8884
# Epoch 9/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1855 - accuracy: 0.9464
# Epoch 10/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0601 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0294 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0558 - accuracy: 0.9911
# Epoch 13/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0246 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0347 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0039 - accuracy: 1.0000
#
#  treinamento 247
#
# Epoch 1/15
# 8/8 [==============================] - 2s 98ms/step - loss: 0.6962 - accuracy: 0.5848
# Epoch 2/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6783 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6938 - accuracy: 0.5938
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6144 - accuracy: 0.7812
# Epoch 5/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.5546 - accuracy: 0.7232
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4428 - accuracy: 0.7455
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2125 - accuracy: 0.9286
# Epoch 8/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3949 - accuracy: 0.8750
# Epoch 9/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0742 - accuracy: 0.9821
# Epoch 10/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1297 - accuracy: 0.9554
# Epoch 11/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0369 - accuracy: 0.9911
# Epoch 12/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0156 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0723 - accuracy: 0.9866
# Epoch 14/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0150 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0108 - accuracy: 1.0000
#
#  treinamento 248
#
# Epoch 1/15
# 8/8 [==============================] - 2s 102ms/step - loss: 0.7697 - accuracy: 0.4777
# Epoch 2/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6532 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7215 - accuracy: 0.6027
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5423 - accuracy: 0.8884
# Epoch 5/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4960 - accuracy: 0.7321
# Epoch 6/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.3736 - accuracy: 0.8482
# Epoch 7/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1201 - accuracy: 0.9732
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4327 - accuracy: 0.7411
# Epoch 9/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0747 - accuracy: 0.9777
# Epoch 10/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0255 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2220 - accuracy: 0.9554
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0650 - accuracy: 0.9777
#
#  treinamento 249
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.7131 - accuracy: 0.5134
# Epoch 2/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6894 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6777 - accuracy: 0.5848
# Epoch 4/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6898 - accuracy: 0.6161
# Epoch 5/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6309 - accuracy: 0.6518
# Epoch 6/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5572 - accuracy: 0.7366
# Epoch 7/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.4986 - accuracy: 0.8616
# Epoch 8/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2475 - accuracy: 0.9286
# Epoch 9/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.2004 - accuracy: 0.9420
# Epoch 10/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0480 - accuracy: 0.9866
# Epoch 11/15
# 8/8 [==============================] - 1s 171ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0556 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0052 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0015 - accuracy: 1.0000
#
#  treinamento 250
#
# Epoch 1/15
# 8/8 [==============================] - 2s 97ms/step - loss: 0.7120 - accuracy: 0.5402
# Epoch 2/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6856 - accuracy: 0.5670
# Epoch 3/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.7129 - accuracy: 0.6071
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6306 - accuracy: 0.7188
# Epoch 5/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6617 - accuracy: 0.7812
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3700 - accuracy: 0.9821
# Epoch 7/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.3129 - accuracy: 0.8527
# Epoch 8/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0761 - accuracy: 0.9866
# Epoch 9/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0789 - accuracy: 0.9777
# Epoch 10/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0162 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.3486 - accuracy: 0.9196
# Epoch 13/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0696 - accuracy: 0.9955
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0013 - accuracy: 1.0000
#
#  treinamento 251
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.7127 - accuracy: 0.4464
# Epoch 2/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6675 - accuracy: 0.5446
# Epoch 3/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.8369 - accuracy: 0.5982
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6548 - accuracy: 0.8170
# Epoch 5/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4512 - accuracy: 0.9330
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6593 - accuracy: 0.7946
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3998 - accuracy: 0.8616
# Epoch 8/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1913 - accuracy: 0.9643
# Epoch 9/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.4203 - accuracy: 0.8393
# Epoch 10/15
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1892 - accuracy: 0.9420
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1482 - accuracy: 0.9643
# Epoch 12/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0771 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0868 - accuracy: 0.9643
# Epoch 14/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0690 - accuracy: 0.9732
# Epoch 15/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0248 - accuracy: 1.0000
#
#  treinamento 252
#
# Epoch 1/15
# 8/8 [==============================] - 2s 98ms/step - loss: 0.8149 - accuracy: 0.5045
# Epoch 2/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6767 - accuracy: 0.6161
# Epoch 3/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6548 - accuracy: 0.6295
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6842 - accuracy: 0.6027
# Epoch 5/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.5269 - accuracy: 0.8080
# Epoch 6/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4057 - accuracy: 0.8393
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3558 - accuracy: 0.8438
# Epoch 8/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1462 - accuracy: 0.9688
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0850 - accuracy: 0.9732
# Epoch 10/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0662 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0745 - accuracy: 0.9777
# Epoch 12/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0977 - accuracy: 0.9107
# Epoch 14/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0181 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0178 - accuracy: 0.9911
#
#  treinamento 253
#
# Epoch 1/15
# 8/8 [==============================] - 2s 97ms/step - loss: 0.7031 - accuracy: 0.5045
# Epoch 2/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.7009 - accuracy: 0.6161
# Epoch 3/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6584 - accuracy: 0.6786
# Epoch 4/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.8086 - accuracy: 0.8348
# Epoch 5/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4430 - accuracy: 0.9018
# Epoch 6/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.3722 - accuracy: 0.9152
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.3067 - accuracy: 0.8929
# Epoch 8/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1046 - accuracy: 0.9777
# Epoch 9/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1431 - accuracy: 0.9509
# Epoch 10/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0222 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0261 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0159 - accuracy: 0.9911
# Epoch 13/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0421 - accuracy: 0.9955
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 1.5960 - accuracy: 0.9330
# Epoch 15/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0549 - accuracy: 0.9911
#
#  treinamento 254
#
# Epoch 1/15
# 8/8 [==============================] - 2s 94ms/step - loss: 0.7595 - accuracy: 0.5848
# Epoch 2/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6744 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6616 - accuracy: 0.6920
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6560 - accuracy: 0.5670
# Epoch 5/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.5616 - accuracy: 0.7188
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5711 - accuracy: 0.7902
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.4793 - accuracy: 0.8527
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2497 - accuracy: 0.9286
# Epoch 9/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1820 - accuracy: 0.9330
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0506 - accuracy: 0.9911
# Epoch 11/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0285 - accuracy: 0.9911
# Epoch 12/15
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0098 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 125ms/step - loss: 0.2298 - accuracy: 0.8973
# Epoch 14/15
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0155 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0083 - accuracy: 0.9955
#
#  treinamento 255
#
# Epoch 1/15
# 8/8 [==============================] - 2s 96ms/step - loss: 0.6987 - accuracy: 0.5223
# Epoch 2/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6897 - accuracy: 0.5804
# Epoch 3/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.7614 - accuracy: 0.6071
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6599 - accuracy: 0.6429
# Epoch 5/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5087 - accuracy: 0.8393
# Epoch 6/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4653 - accuracy: 0.8482
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.3719 - accuracy: 0.9018
# Epoch 8/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2357 - accuracy: 0.8839
# Epoch 9/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1420 - accuracy: 0.9509
# Epoch 10/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0234 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0258 - accuracy: 0.9955
# Epoch 12/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1498 - accuracy: 0.9509
# Epoch 15/15
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0018 - accuracy: 1.0000
#
#  treinamento 256
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.7251 - accuracy: 0.5580
# Epoch 2/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6898 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6911 - accuracy: 0.5446
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6343 - accuracy: 0.7188
# Epoch 5/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.7561 - accuracy: 0.8036
# Epoch 6/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5167 - accuracy: 0.9018
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.4298 - accuracy: 0.8705
# Epoch 8/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2817 - accuracy: 0.9062
# Epoch 9/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1249 - accuracy: 0.9598
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3546 - accuracy: 0.8482
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0415 - accuracy: 0.9955
# Epoch 12/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1991 - accuracy: 0.9598
# Epoch 13/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0033 - accuracy: 1.0000
#
#  treinamento 257
#
# Epoch 1/15
# 8/8 [==============================] - 2s 94ms/step - loss: 0.7835 - accuracy: 0.5223
# Epoch 2/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6691 - accuracy: 0.5402
# Epoch 3/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6346 - accuracy: 0.6027
# Epoch 4/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6854 - accuracy: 0.7946
# Epoch 5/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.7027 - accuracy: 0.6786
# Epoch 6/15
# 8/8 [==============================] - 1s 107ms/step - loss: 0.4494 - accuracy: 0.9196
# Epoch 7/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4644 - accuracy: 0.9062
# Epoch 8/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4202 - accuracy: 0.8929
# Epoch 9/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1754 - accuracy: 0.9509
# Epoch 10/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1708 - accuracy: 0.9509
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0287 - accuracy: 0.9955
# Epoch 12/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1426 - accuracy: 0.9554
# Epoch 13/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2700 - accuracy: 0.8705
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0194 - accuracy: 0.9911
# Epoch 15/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0193 - accuracy: 0.9955
#
#  treinamento 258
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.6980 - accuracy: 0.5402
# Epoch 2/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.7118 - accuracy: 0.5893
# Epoch 3/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6240 - accuracy: 0.6161
# Epoch 4/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5614 - accuracy: 0.7277
# Epoch 5/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5119 - accuracy: 0.7232
# Epoch 6/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.4222 - accuracy: 0.8348
# Epoch 7/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2540 - accuracy: 0.9420
# Epoch 8/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0671 - accuracy: 0.9777
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 10/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1137 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0139 - accuracy: 0.9955
# Epoch 14/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 98ms/step - loss: 5.9964e-04 - accuracy: 1.0000
#
#  treinamento 259
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.7097 - accuracy: 0.5312
# Epoch 2/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6424 - accuracy: 0.7098
# Epoch 3/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6694 - accuracy: 0.5491
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.5894 - accuracy: 0.8125
# Epoch 5/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6072 - accuracy: 0.6741
# Epoch 6/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3992 - accuracy: 0.8304
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2583 - accuracy: 0.8661
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1689 - accuracy: 0.9509
# Epoch 9/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0421 - accuracy: 0.9821
# Epoch 10/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0218 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0116 - accuracy: 0.9955
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1108 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0018 - accuracy: 1.0000
#
#  treinamento 260
#
# Epoch 1/15
# 8/8 [==============================] - 2s 98ms/step - loss: 0.7256 - accuracy: 0.5223
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6875 - accuracy: 0.5312
# Epoch 3/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6681 - accuracy: 0.6920
# Epoch 4/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6893 - accuracy: 0.7500
# Epoch 5/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6375 - accuracy: 0.7946
# Epoch 6/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4177 - accuracy: 0.8884
# Epoch 7/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3345 - accuracy: 0.8705
# Epoch 8/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1417 - accuracy: 0.9598
# Epoch 9/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1558 - accuracy: 0.8973
# Epoch 10/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0615 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0584 - accuracy: 0.9866
# Epoch 13/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0121 - accuracy: 0.9955
#
#  treinamento 261
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.7062 - accuracy: 0.6027
# Epoch 2/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6683 - accuracy: 0.6295
# Epoch 3/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6791 - accuracy: 0.6607
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5927 - accuracy: 0.7455
# Epoch 5/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6193 - accuracy: 0.7500
# Epoch 6/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4674 - accuracy: 0.7991
# Epoch 7/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1701 - accuracy: 0.9464
# Epoch 8/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.5071 - accuracy: 0.8616
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1792 - accuracy: 0.9598
# Epoch 10/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2928 - accuracy: 0.9062
# Epoch 11/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0526 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0532 - accuracy: 0.9821
# Epoch 13/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1602 - accuracy: 0.9688
#
#  treinamento 262
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.6921 - accuracy: 0.5223
# Epoch 2/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6912 - accuracy: 0.4598
# Epoch 3/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6715 - accuracy: 0.5670
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6836 - accuracy: 0.6429
# Epoch 5/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6609 - accuracy: 0.6830
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4555 - accuracy: 0.7946
# Epoch 7/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2103 - accuracy: 0.9643
# Epoch 8/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2421 - accuracy: 0.9152
# Epoch 9/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0564 - accuracy: 0.9777
# Epoch 10/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 11/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 96ms/step - loss: 4.4103e-04 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 96ms/step - loss: 2.2803e-04 - accuracy: 1.0000
#
#  treinamento 263
#
# Epoch 1/15
# 8/8 [==============================] - 2s 104ms/step - loss: 0.7179 - accuracy: 0.4598
# Epoch 2/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6823 - accuracy: 0.5402
# Epoch 3/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6678 - accuracy: 0.5223
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6592 - accuracy: 0.6116
# Epoch 5/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.5837 - accuracy: 0.8170
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5223 - accuracy: 0.7232
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4635 - accuracy: 0.8705
# Epoch 8/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.3014 - accuracy: 0.9286
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1300 - accuracy: 0.9955
# Epoch 10/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0489 - accuracy: 0.9911
# Epoch 11/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.3121 - accuracy: 0.9598
# Epoch 12/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0507 - accuracy: 0.9866
# Epoch 13/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0248 - accuracy: 0.9866
# Epoch 14/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0534 - accuracy: 0.9821
#
#  treinamento 264
#
# Epoch 1/15
# 8/8 [==============================] - 2s 104ms/step - loss: 0.7470 - accuracy: 0.5491
# Epoch 2/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6787 - accuracy: 0.6205
# Epoch 3/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6488 - accuracy: 0.6205
# Epoch 4/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.5715 - accuracy: 0.6696
# Epoch 5/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.5308 - accuracy: 0.6875
# Epoch 6/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2708 - accuracy: 0.9286
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2976 - accuracy: 0.9241
# Epoch 8/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1155 - accuracy: 0.9732
# Epoch 9/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0724 - accuracy: 0.9911
# Epoch 10/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0328 - accuracy: 0.9911
# Epoch 11/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0943 - accuracy: 0.9777
# Epoch 12/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0122 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0184 - accuracy: 1.0000
#
#  treinamento 265
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.7956 - accuracy: 0.5580
# Epoch 2/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6666 - accuracy: 0.5670
# Epoch 3/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6802 - accuracy: 0.6920
# Epoch 4/15
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6116 - accuracy: 0.7232
# Epoch 5/15
# 8/8 [==============================] - 1s 135ms/step - loss: 0.7163 - accuracy: 0.8125
# Epoch 6/15
# 8/8 [==============================] - 1s 125ms/step - loss: 0.4937 - accuracy: 0.7768
# Epoch 7/15
# 8/8 [==============================] - 1s 113ms/step - loss: 0.4381 - accuracy: 0.8795
# Epoch 8/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6383 - accuracy: 0.8571
# Epoch 9/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1920 - accuracy: 0.9598
# Epoch 10/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0932 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2770 - accuracy: 0.9420
# Epoch 12/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0698 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0341 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1166 - accuracy: 0.9598
#
#  treinamento 266
#
# Epoch 1/15
# 8/8 [==============================] - 2s 98ms/step - loss: 0.7145 - accuracy: 0.5312
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6798 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6304 - accuracy: 0.7545
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.7654 - accuracy: 0.6518
# Epoch 5/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5828 - accuracy: 0.7054
# Epoch 6/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6370 - accuracy: 0.8036
# Epoch 7/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.4070 - accuracy: 0.9286
# Epoch 8/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.4199 - accuracy: 0.8125
# Epoch 9/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1591 - accuracy: 0.9375
# Epoch 10/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1796 - accuracy: 0.9732
# Epoch 11/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0316 - accuracy: 0.9911
# Epoch 12/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1022 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0267 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0033 - accuracy: 1.0000
#
#  treinamento 267
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.6878 - accuracy: 0.5804
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6965 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6695 - accuracy: 0.5045
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6911 - accuracy: 0.6429
# Epoch 5/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5452 - accuracy: 0.7411
# Epoch 6/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3565 - accuracy: 0.8661
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2582 - accuracy: 0.9241
# Epoch 8/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4206 - accuracy: 0.8125
# Epoch 9/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2367 - accuracy: 0.9330
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0204 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0110 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0151 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0022 - accuracy: 1.0000
#
#  treinamento 268
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.8527 - accuracy: 0.6027
# Epoch 2/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6627 - accuracy: 0.6116
# Epoch 3/15
# 8/8 [==============================] - 1s 108ms/step - loss: 0.6353 - accuracy: 0.6250
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6891 - accuracy: 0.7188
# Epoch 5/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6628 - accuracy: 0.8661
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4940 - accuracy: 0.7500
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2829 - accuracy: 0.9464
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1508 - accuracy: 0.9688
# Epoch 9/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1816 - accuracy: 0.9643
# Epoch 10/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0391 - accuracy: 0.9866
# Epoch 11/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0380 - accuracy: 0.9955
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1063 - accuracy: 0.9821
# Epoch 13/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0013 - accuracy: 1.0000
#
#  treinamento 269
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.8050 - accuracy: 0.5625
# Epoch 2/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6639 - accuracy: 0.6250
# Epoch 3/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6262 - accuracy: 0.5670
# Epoch 4/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6150 - accuracy: 0.7009
# Epoch 5/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5702 - accuracy: 0.8393
# Epoch 6/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.4347 - accuracy: 0.8482
# Epoch 7/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2263 - accuracy: 0.9420
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1158 - accuracy: 0.9821
# Epoch 9/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0614 - accuracy: 0.9866
# Epoch 10/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0899 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0764 - accuracy: 0.9821
# Epoch 13/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1881 - accuracy: 0.9464
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0051 - accuracy: 1.0000
#
#  treinamento 270
#
# Epoch 1/15
# 8/8 [==============================] - 2s 97ms/step - loss: 0.7488 - accuracy: 0.4866
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6825 - accuracy: 0.5714
# Epoch 3/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.7446 - accuracy: 0.5982
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5653 - accuracy: 0.7902
# Epoch 5/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5880 - accuracy: 0.8214
# Epoch 6/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4854 - accuracy: 0.8304
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3464 - accuracy: 0.8214
# Epoch 8/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1760 - accuracy: 0.9598
# Epoch 9/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1746 - accuracy: 0.9509
# Epoch 10/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0318 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1345 - accuracy: 0.9732
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0284 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0389 - accuracy: 0.9911
#
#  treinamento 271
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.7244 - accuracy: 0.5179
# Epoch 2/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6749 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6910 - accuracy: 0.5223
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6546 - accuracy: 0.7946
# Epoch 5/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.5791 - accuracy: 0.7411
# Epoch 6/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.4067 - accuracy: 0.9062
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3197 - accuracy: 0.8929
# Epoch 8/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1748 - accuracy: 0.9509
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1851 - accuracy: 0.8929
# Epoch 10/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0667 - accuracy: 0.9732
# Epoch 11/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0444 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0212 - accuracy: 0.9911
# Epoch 13/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1005 - accuracy: 0.9688
# Epoch 14/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0910 - accuracy: 0.9777
# Epoch 15/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0139 - accuracy: 0.9955
#
#  treinamento 272
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.7447 - accuracy: 0.5848
# Epoch 2/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6637 - accuracy: 0.6562
# Epoch 3/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6282 - accuracy: 0.6295
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6335 - accuracy: 0.7500
# Epoch 5/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.3451 - accuracy: 0.9107
# Epoch 6/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2600 - accuracy: 0.9062
# Epoch 7/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.2327 - accuracy: 0.9062
# Epoch 8/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1794 - accuracy: 0.9375
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0333 - accuracy: 0.9955
# Epoch 10/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0848 - accuracy: 0.9821
# Epoch 11/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0222 - accuracy: 0.9955
# Epoch 12/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0581 - accuracy: 0.9821
# Epoch 13/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0488 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0257 - accuracy: 0.9911
#
#  treinamento 273
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.9091 - accuracy: 0.5759
# Epoch 2/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6576 - accuracy: 0.6027
# Epoch 3/15
# 8/8 [==============================] - 1s 92ms/step - loss: 0.5965 - accuracy: 0.6339
# Epoch 4/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6068 - accuracy: 0.6339
# Epoch 5/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6245 - accuracy: 0.7946
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6270 - accuracy: 0.8348
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3236 - accuracy: 0.8438
# Epoch 8/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.3922 - accuracy: 0.8214
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0925 - accuracy: 0.9777
# Epoch 10/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0241 - accuracy: 0.9911
# Epoch 11/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2005 - accuracy: 0.9509
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 4.0282e-04 - accuracy: 1.0000
#
#  treinamento 274
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.7119 - accuracy: 0.5312
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6834 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6879 - accuracy: 0.5268
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6485 - accuracy: 0.6429
# Epoch 5/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6312 - accuracy: 0.7143
# Epoch 6/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5234 - accuracy: 0.7991
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3780 - accuracy: 0.8438
# Epoch 8/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2389 - accuracy: 0.9241
# Epoch 9/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0807 - accuracy: 0.9821
# Epoch 10/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.2404 - accuracy: 0.9554
# Epoch 11/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0301 - accuracy: 0.9911
# Epoch 12/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0150 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1270 - accuracy: 0.9062
# Epoch 15/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.2210 - accuracy: 0.9420
#
#  treinamento 275
#
# Epoch 1/15
# 8/8 [==============================] - 2s 100ms/step - loss: 0.8117 - accuracy: 0.5580
# Epoch 2/15
# 8/8 [==============================] - 1s 94ms/step - loss: 0.6546 - accuracy: 0.6920
# Epoch 3/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6404 - accuracy: 0.6830
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6184 - accuracy: 0.8036
# Epoch 5/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.5139 - accuracy: 0.8661
# Epoch 6/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.4367 - accuracy: 0.7589
# Epoch 7/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2912 - accuracy: 0.9062
# Epoch 8/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1840 - accuracy: 0.9598
# Epoch 9/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0431 - accuracy: 0.9911
# Epoch 10/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2891 - accuracy: 0.8616
# Epoch 11/15
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0417 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0158 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0151 - accuracy: 0.9955
# Epoch 15/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0076 - accuracy: 0.9955
#
#  treinamento 276
#
# Epoch 1/15
# 8/8 [==============================] - 2s 98ms/step - loss: 0.7071 - accuracy: 0.5312
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6894 - accuracy: 0.5759
# Epoch 3/15
# 8/8 [==============================] - 1s 127ms/step - loss: 0.6625 - accuracy: 0.6116
# Epoch 4/15
# 8/8 [==============================] - 1s 132ms/step - loss: 0.6406 - accuracy: 0.6652
# Epoch 5/15
# 8/8 [==============================] - 1s 121ms/step - loss: 0.5348 - accuracy: 0.7589
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3242 - accuracy: 0.9152
# Epoch 7/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1296 - accuracy: 0.9554
# Epoch 8/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.4812 - accuracy: 0.8795
# Epoch 10/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0558 - accuracy: 0.9866
# Epoch 11/15
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0219 - accuracy: 0.9955
# Epoch 13/15
# ...
# Epoch 7/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.4307 - accuracy: 0.8616
# Epoch 8/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2928 - accuracy: 0.9375
# Epoch 9/15
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1314 - accuracy: 0.9821
# Epoch 10/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.2006 - accuracy: 0.8795
# Epoch 11/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0739 - accuracy: 0.9777
# Epoch 12/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0307 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0727 - accuracy: 0.9732
# Epoch 14/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1911 - accuracy: 0.9732
#
#  treinamento 386
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.9740 - accuracy: 0.5491
# Epoch 2/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6820 - accuracy: 0.5357
# Epoch 3/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.6593 - accuracy: 0.6161
# Epoch 4/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6100 - accuracy: 0.6339
# Epoch 5/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.5586 - accuracy: 0.7098
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6333 - accuracy: 0.8438
# Epoch 7/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.4510 - accuracy: 0.8214
# Epoch 8/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2266 - accuracy: 0.9152
# Epoch 9/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2073 - accuracy: 0.9330
# Epoch 10/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1367 - accuracy: 0.9598
# Epoch 11/15
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0343 - accuracy: 0.9911
# Epoch 12/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0107 - accuracy: 0.9955
# Epoch 13/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2987 - accuracy: 0.8929
# Epoch 14/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0422 - accuracy: 0.9821
# Epoch 15/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0111 - accuracy: 1.0000
#
#  treinamento 387
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.7064 - accuracy: 0.5045
# Epoch 2/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6800 - accuracy: 0.6027
# Epoch 3/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.7042 - accuracy: 0.6518
# Epoch 4/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6259 - accuracy: 0.6607
# Epoch 5/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.5813 - accuracy: 0.6875
# Epoch 6/15
# 8/8 [==============================] - 1s 110ms/step - loss: 0.6737 - accuracy: 0.8304
# Epoch 7/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2818 - accuracy: 0.9196
# Epoch 8/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1474 - accuracy: 0.9509
# Epoch 9/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2884 - accuracy: 0.9107
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1473 - accuracy: 0.9464
# Epoch 11/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1062 - accuracy: 0.9643
# Epoch 13/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3711 - accuracy: 0.8884
# Epoch 14/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1563 - accuracy: 0.8929
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0666 - accuracy: 0.9911
#
#  treinamento 388
#
# Epoch 1/15
# 8/8 [==============================] - 2s 99ms/step - loss: 0.7120 - accuracy: 0.5045
# Epoch 2/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6939 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6848 - accuracy: 0.6964
# Epoch 4/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6560 - accuracy: 0.6652
# Epoch 5/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6111 - accuracy: 0.7321
# Epoch 6/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5107 - accuracy: 0.7589
# Epoch 7/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3373 - accuracy: 0.8393
# Epoch 8/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2244 - accuracy: 0.9375
# Epoch 9/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2625 - accuracy: 0.8795
# Epoch 10/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0831 - accuracy: 0.9777
# Epoch 11/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0325 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1772 - accuracy: 0.9018
# Epoch 13/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0358 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0323 - accuracy: 0.9955
#
#  treinamento 389
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.7200 - accuracy: 0.5759
# Epoch 2/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.7355 - accuracy: 0.5491
# Epoch 3/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6715 - accuracy: 0.6696
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6464 - accuracy: 0.7411
# Epoch 5/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5808 - accuracy: 0.7411
# Epoch 6/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.5877 - accuracy: 0.8482
# Epoch 7/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2140 - accuracy: 0.9598
# Epoch 8/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2632 - accuracy: 0.9286
# Epoch 9/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0918 - accuracy: 0.9777
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 11/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2172 - accuracy: 0.8884
# Epoch 12/15
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0749 - accuracy: 0.9866
# Epoch 13/15
# 8/8 [==============================] - 1s 118ms/step - loss: 0.0158 - accuracy: 0.9955
# Epoch 14/15
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0031 - accuracy: 1.0000
#
#  treinamento 390
#
# Epoch 1/15
# 8/8 [==============================] - 2s 105ms/step - loss: 0.7134 - accuracy: 0.5045
# Epoch 2/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.6824 - accuracy: 0.6116
# Epoch 3/15
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6728 - accuracy: 0.6473
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6729 - accuracy: 0.5670
# Epoch 5/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6359 - accuracy: 0.8259
# Epoch 6/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.5000 - accuracy: 0.7991
# Epoch 7/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2742 - accuracy: 0.9286
# Epoch 8/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1784 - accuracy: 0.9330
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0806 - accuracy: 0.9821
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0162 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0416 - accuracy: 0.9866
# Epoch 12/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0669 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0015 - accuracy: 1.0000
#
#  treinamento 391
#
# Epoch 1/15
# 8/8 [==============================] - 2s 102ms/step - loss: 0.7742 - accuracy: 0.6116
# Epoch 2/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6682 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6155 - accuracy: 0.5714
# Epoch 4/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6402 - accuracy: 0.6875
# Epoch 5/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.4291 - accuracy: 0.8884
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3750 - accuracy: 0.8571
# Epoch 7/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2221 - accuracy: 0.9330
# Epoch 8/15
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1164 - accuracy: 0.9688
# Epoch 9/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0258 - accuracy: 0.9955
# Epoch 10/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0317 - accuracy: 0.9911
# Epoch 11/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1020 - accuracy: 0.9464
# Epoch 12/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0522 - accuracy: 0.9777
# Epoch 13/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0113 - accuracy: 0.9911
# Epoch 14/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0426 - accuracy: 0.9777
# Epoch 15/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0139 - accuracy: 0.9955
#
#  treinamento 392
#
# Epoch 1/15
# 8/8 [==============================] - 2s 102ms/step - loss: 0.7927 - accuracy: 0.5402
# Epoch 2/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6831 - accuracy: 0.6786
# Epoch 3/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6332 - accuracy: 0.5759
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5917 - accuracy: 0.7946
# Epoch 5/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5774 - accuracy: 0.9062
# Epoch 6/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5070 - accuracy: 0.7321
# Epoch 7/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3707 - accuracy: 0.8750
# Epoch 8/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.2260 - accuracy: 0.9286
# Epoch 9/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1764 - accuracy: 0.9464
# Epoch 10/15
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0788 - accuracy: 0.9732
# Epoch 11/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 12/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 13/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1030 - accuracy: 0.9241
# Epoch 14/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0388 - accuracy: 0.9777
# Epoch 15/15
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0058 - accuracy: 1.0000
#
#  treinamento 393
#
# Epoch 1/15
# 8/8 [==============================] - 2s 104ms/step - loss: 0.6952 - accuracy: 0.4866
# Epoch 2/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.6927 - accuracy: 0.5714
# Epoch 3/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6689 - accuracy: 0.7143
# Epoch 4/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6697 - accuracy: 0.7902
# Epoch 5/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6978 - accuracy: 0.8036
# Epoch 6/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.3971 - accuracy: 0.9241
# Epoch 7/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3540 - accuracy: 0.8482
# Epoch 8/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2176 - accuracy: 0.9420
# Epoch 9/15
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1133 - accuracy: 0.9955
# Epoch 10/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0262 - accuracy: 0.9955
# Epoch 11/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1068 - accuracy: 0.9598
# Epoch 12/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0407 - accuracy: 0.9866
# Epoch 13/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0047 - accuracy: 1.0000
#
#  treinamento 394
#
# Epoch 1/15
# 8/8 [==============================] - 2s 101ms/step - loss: 0.8659 - accuracy: 0.5491
# Epoch 2/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6623 - accuracy: 0.6429
# Epoch 3/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.7506 - accuracy: 0.5402
# Epoch 4/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6232 - accuracy: 0.8036
# Epoch 5/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.5899 - accuracy: 0.6920
# Epoch 6/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.4426 - accuracy: 0.7277
# Epoch 7/15
# 8/8 [==============================] - 1s 106ms/step - loss: 0.5520 - accuracy: 0.8527
# Epoch 8/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2909 - accuracy: 0.9420
# Epoch 9/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2204 - accuracy: 0.9241
# Epoch 10/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1207 - accuracy: 0.9643
# Epoch 11/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0931 - accuracy: 0.9732
# Epoch 12/15
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0298 - accuracy: 0.9911
# Epoch 13/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0626 - accuracy: 0.9464
# Epoch 14/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0858 - accuracy: 0.9643
# Epoch 15/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0120 - accuracy: 1.0000
#
#  treinamento 395
#
# Epoch 1/15
# 8/8 [==============================] - 2s 102ms/step - loss: 0.7800 - accuracy: 0.5134
# Epoch 2/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6840 - accuracy: 0.5848
# Epoch 3/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6810 - accuracy: 0.5848
# Epoch 4/15
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6748 - accuracy: 0.6562
# Epoch 5/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7064 - accuracy: 0.7500
# Epoch 6/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5259 - accuracy: 0.8125
# Epoch 7/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.3620 - accuracy: 0.9196
# Epoch 8/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4605 - accuracy: 0.8393
# Epoch 9/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1500 - accuracy: 0.9598
# Epoch 10/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2206 - accuracy: 0.8929
# Epoch 11/15
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0628 - accuracy: 0.9821
# Epoch 12/15
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0485 - accuracy: 0.9866
# Epoch 13/15
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1124 - accuracy: 0.9688
# Epoch 15/15
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0087 - accuracy: 1.0000
#
#  treinamento 396
#
# Epoch 1/15
# 4/8 [==============>...............] - ETA: 0s - loss: 0.7461 - accuracy: 0.4554

# %%
# acc9 = list(range(n))
  

# try:
#   assert f'model9({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

# except:
#   print(f'model9({n})  já existe em /content/drive/MyDrive/TCC/Videos')
  
# else:
#   with open(f'model9({n})t.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
#     m.write('Treinamento,Accuracy\n')

#   for i in range(n): 
#     print(f'\n treinamento {i+1} \n')

#     model9 = modelo_9()
#     report9 = model9.fit(imagens_treinamento,
#               steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
#               epochs=35,     
#               verbose=0,
#               callbacks= [CustomCallback()])

#     acc9[i] = report9.history['accuracy'][-1]

#     with open(f'model1({n})t.txt', 'a+') as m:    # 'a+' adiciona ao arquivo existente os valores
#       m.write(f'{i+1}, {acc1[i]} \n')

# try:
#   shutil.move(f'/content/drive/MyDrive/TCC/Videos/model9({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')

# except:
#   print('modelo 9 nao foi movido')

# %%
# acc10 = list(range(n))
  

# try:
#   assert f'model10({n})t.txt' not in os.listdir('/content/drive/MyDrive/TCC/Videos')  # verifica se existe o arquivo no drive

# except:
#   print(f'model10({n})  já existe em /content/drive/MyDrive/TCC/Videos')
  
# else:
#   with open(f'model10({n})t.txt', 'w') as m:    # 'w' cria o arquivo para receber os valores caso ele não exista 
#     m.write('Treinamento,Accuracy\n')

#   for i in range(n): 
#     print(f'\n treinamento {i+1} \n')

#     model10 = modelo_10()
#     report10 = model10.fit(imagens_treinamento,
#               steps_per_epoch=8,  # total de x imagens e cada batch com y imagens , logo o passo será x/y 
#               epochs=27,     
#               verbose=0,
#               callbacks= [CustomCallback()])

#     acc10[i] = report10.history['accuracy'][-1]

#     with open(f'model1({n})t.txt', 'a+') as m:    # 'a+' adiciona ao arquivo existente os valores
#       m.write(f'{i+1}, {acc1[i]} \n')

# try:
#   shutil.move(f'/content/drive/MyDrive/TCC/Videos/model10({n})t.txt', '/content/drive/MyDrive/TCC/Scripts/Modelos')

# except:
#   print('modelo 10 nao foi movido')

# %% [markdown]
# #### Testes

# %%
aqui = [0.1,0.5,0.77]

# %%
with open('teste', 'w') as t:  #https://docs.python.org/pt-br/3/tutorial/inputoutput.html#reading-and-writing-files
  t.write(f'{aqui}')
  t.write('adeus')
  print(t)
# Out:
# <_io.TextIOWrapper name='teste' mode='w' encoding='UTF-8'>

# %%
with open('teste', 'w') as t:
  t.readline(1)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-135-fa77f0a17d79> in <module>
#       1 with open('teste', 'w') as t:
# ----> 2   t.readline(1)
#
# UnsupportedOperation: not readable

# %%
with open('/trainHistoryDict', 'wb') as file_pi:   #https://stackoverflow.com/questions/41061457/keras-how-to-save-the-training-history-attribute-of-the-history-object
    pickle.dump(model.history, file_pi)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/TCC/Videos
